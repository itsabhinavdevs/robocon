# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(
    data = "C:\Users\abhi\Desktop\robocon\dataset_raw\robo\data.yaml",
    epochs = 100,
    imgsz = 640,
    batch =8,
    name = "robocon_test_model",
    device = 0,
)
